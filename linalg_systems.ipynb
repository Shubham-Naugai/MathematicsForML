# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from mpl_toolkits.mplot3d import Axes3D
from IPython import display
import time
from sympy import *

# %% [markdown]
# # Systems of equations: algebra and geometry

# %%
# 3 these are the coefficients of the equation:
# ay = bx + c;
eq1o = [1., 2, 1] # [a b c]
eq2o = [2., 1, 3]


for i in range(10):
    
    # clear plot
    plt.cla()
    
    # randomly update equations
    eq1 = np.add(eq2o,np.random.randn(1)*eq1o)
    eq2 = np.add(eq1o,np.random.randn(1)*eq2o)
    
    # plot new lines (solutions)
    y = ([eq1[1]*-3, eq1[1]*3] + eq1[2])/eq1[0]
    plt.plot([-3,3],y)
    
    y = ([eq2[1]*-3, eq2[1]*3] + eq2[2])/eq2[0]
    plt.plot([-3,3],y)
    plt.axis([-3,3,-3,6])
    plt.grid()
    
    # pause to allow inspection
    display.clear_output(wait=True)
    display.display(plt.gcf())
    time.sleep(.1)

# %%
# these are the coefficients of the equation:
# az = bx + cy + d
eq1o = [1, 2, 3, -1] # [a b c d]
eq2o = [2, 1, 3,  3]

# set up for 3D plot
fig = plt.figure()
ax = fig.gca(projection='3d')


for i in range(0,10):
    
#     plt.cla()
    
    # randomly update equations
    eq1 = np.add(eq2o,np.random.randn(1)*eq1o)
    eq2 = np.add(eq1o,np.random.randn(1)*eq2o)
    
    # plot new lines (solutions)
    y = ([eq1[1]*-3, eq1[1]*3] + eq1[3])/eq1[0]
    z = ([eq1[2]*-3, eq1[2]*3] + eq1[3])/eq1[0]
    ax.plot([-3,3],y,z)
    
    # plot new lines (solutions)
    y = ([eq2[1]*-3, eq2[1]*3] + eq2[3])/eq2[0]
    z = ([eq2[2]*-3, eq2[2]*3] + eq2[3])/eq2[0]
    ax.plot([-3,3],y,z)
    
    # axis limits
    ax.set_xlim3d(-3,6)
    ax.set_ylim3d(-3,6)
    ax.set_zlim3d(-1,10)
    
    # pause to allow inspection
    display.clear_output(wait=True)
    display.display(plt.gcf())
    time.sleep(.1)

# %% [markdown]
# # Reduced row echelon form

# %%
# make some random matrices (using sympy package)
"""
In numpy there is no function to calculate RREF of a matrix
But sympy has, so for that we have to convert our numpy array into sympy matrix
"""
A = Matrix(np.random.randn(4,4))
B = Matrix(np.random.randn(4,3))

# compute RREF
rrefA = A.rref()
rrefB = B.rref()

# print out the matrix and its rref
print(np.array(rrefA[0]))
print(' ')
print(np.array(rrefB[0]))

# %%
# Code Practice : RREF of with different sizes and rank
# -square
m = 5
n = 5

SA = Matrix(np.random.randn(m, n))
rrefSA = SA.rref()
print(np.array(rrefA[0]))
print()


# -rectangular (tall, wide)
m = 8
n = 5

TA = Matrix(np.random.randn(m, n))
rrefTA = TA.rref()
print(np.array(rrefTA[0]))
print()


m = 3
n = 6

WA = Matrix(np.random.randn(m, n))
rrefWA = WA.rref()
print(np.array(rrefWA[0]))
print()


# -linear dependencies (columns, rows)
m = 5
n = 5

A = Matrix(np.random.randn(m, n))
A[:, 0] = A[:, 1]
rrefA = A.rref()
print(np.array(rrefA[0]))
